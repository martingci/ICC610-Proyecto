# %% [markdown]
# # Generación de archivos con Miner

# %% [markdown]
# ## Se definen las rutas a utilizar

# %%
from pathlib import Path


RUTA_BASE = Path.cwd().parent
RUTA_REPOS = RUTA_BASE / "miner" / "repos"
RUTA_RESULTADOS = RUTA_BASE / "results"

# %% [markdown]
# ## Paso 1: Obtener y clonar repositorios de Github

# %%
from generate_github_api import GetReposGitHubAPI

github_org = "vercel"
cantidad_repos = 25
github_api = GetReposGitHubAPI(str(RUTA_REPOS), github_org)
github_api.run(cantidad_repos)
# Out:
# Clonando el repositorio next.js desde https://github.com/vercel/next.js.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/next.js...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/next.js'...
# Updating files: 100% (32471/32471), done.
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/hyper'...
# Clonando el repositorio hyper desde https://github.com/vercel/hyper.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/hyper...
# Clonando el repositorio swr desde https://github.com/vercel/swr.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/swr...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/swr'...
# Clonando el repositorio ai desde https://github.com/vercel/ai.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/ai...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/ai'...
# Clonando el repositorio pkg desde https://github.com/vercel/pkg.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/pkg...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/pkg'...
# Clonando el repositorio chatbot desde https://github.com/vercel/chatbot.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/chatbot...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/chatbot'...
# Clonando el repositorio vercel desde https://github.com/vercel/vercel.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/vercel...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/vercel'...
# Updating files: 100% (13930/13930), done.
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/commerce'...
# Clonando el repositorio commerce desde https://github.com/vercel/commerce.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/commerce...
# Clonando el repositorio satori desde https://github.com/vercel/satori.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/satori...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/satori'...
# Clonando el repositorio micro desde https://github.com/vercel/micro.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/micro...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/micro'...
# Clonando el repositorio serve desde https://github.com/vercel/serve.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/serve...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/serve'...
# Clonando el repositorio ncc desde https://github.com/vercel/ncc.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/ncc...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/ncc'...
# Clonando el repositorio styled-jsx desde https://github.com/vercel/styled-jsx.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/styled-jsx...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/styled-jsx'...
# Clonando el repositorio nextjs-subscription-payments desde https://github.com/vercel/nextjs-subscription-payments.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/nextjs-subscription-payments...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/nextjs-subscription-payments'...
# Clonando el repositorio next-forge desde https://github.com/vercel/next-forge.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/next-forge...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/next-forge'...
# Clonando el repositorio platforms desde https://github.com/vercel/platforms.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/platforms...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/platforms'...
# Clonando el repositorio streamdown desde https://github.com/vercel/streamdown.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/streamdown...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/streamdown'...
# Clonando el repositorio ms desde https://github.com/vercel/ms.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/ms...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/ms'...
# Clonando el repositorio eve desde https://github.com/vercel/eve.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/eve...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/eve'...
# Clonando el repositorio examples desde https://github.com/vercel/examples.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/examples...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/examples'...
# Clonando el repositorio next-learn desde https://github.com/vercel/next-learn.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/next-learn...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/next-learn'...
# Clonando el repositorio og-image desde https://github.com/vercel/og-image.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/og-image...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/og-image'...
# Clonando el repositorio release desde https://github.com/vercel/release.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/release...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/release'...
# Clonando el repositorio hazel desde https://github.com/vercel/hazel.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/hazel...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/hazel'...
# Clonando el repositorio next-app-router-playground desde https://github.com/vercel/next-app-router-playground.git a /workspaces/Proyecto-Ciberseguridad/miner/repos/next-app-router-playground...
# Cloning into '/workspaces/Proyecto-Ciberseguridad/miner/repos/next-app-router-playground'...

# %% [markdown]
# ## Paso 2: Generar SBOMs con Syft

# %%
from generate_sboms import SBOMGenerator

sbom_generator = SBOMGenerator(str(RUTA_REPOS), str(RUTA_RESULTADOS))
sbom_generator.run()
# Out:
# INFO | Usando Syft CLI: /usr/local/bin/syft
# INFO | [1/25] Procesando repositorio miner/repos/ai
# INFO | SBOM guardado en results/ai-sbom.json
# INFO | [2/25] Procesando repositorio miner/repos/chatbot
# INFO | SBOM guardado en results/chatbot-sbom.json
# INFO | [3/25] Procesando repositorio miner/repos/commerce
# INFO | SBOM guardado en results/commerce-sbom.json
# INFO | [4/25] Procesando repositorio miner/repos/eve
# INFO | SBOM guardado en results/eve-sbom.json
# INFO | [5/25] Procesando repositorio miner/repos/examples
# INFO | SBOM guardado en results/examples-sbom.json
# INFO | [6/25] Procesando repositorio miner/repos/hazel
# INFO | SBOM guardado en results/hazel-sbom.json
# INFO | [7/25] Procesando repositorio miner/repos/hyper
# INFO | SBOM guardado en results/hyper-sbom.json
# INFO | [8/25] Procesando repositorio miner/repos/micro
# INFO | SBOM guardado en results/micro-sbom.json
# INFO | [9/25] Procesando repositorio miner/repos/ms
# INFO | SBOM guardado en results/ms-sbom.json
# INFO | [10/25] Procesando repositorio miner/repos/ncc
# INFO | SBOM guardado en results/ncc-sbom.json
# INFO | [11/25] Procesando repositorio miner/repos/next-app-router-playground
# INFO | SBOM guardado en results/next-app-router-playground-sbom.json
# INFO | [12/25] Procesando repositorio miner/repos/next-forge
# INFO | SBOM guardado en results/next-forge-sbom.json
# INFO | [13/25] Procesando repositorio miner/repos/next-learn
# INFO | SBOM guardado en results/next-learn-sbom.json
# INFO | [14/25] Procesando repositorio miner/repos/next.js
# INFO | SBOM guardado en results/next.js-sbom.json
# INFO | [15/25] Procesando repositorio miner/repos/nextjs-subscription-payments
# INFO | SBOM guardado en results/nextjs-subscription-payments-sbom.json
# INFO | [16/25] Procesando repositorio miner/repos/og-image
# INFO | SBOM guardado en results/og-image-sbom.json
# INFO | [17/25] Procesando repositorio miner/repos/pkg
# INFO | SBOM guardado en results/pkg-sbom.json
# INFO | [18/25] Procesando repositorio miner/repos/platforms
# INFO | SBOM guardado en results/platforms-sbom.json
# INFO | [19/25] Procesando repositorio miner/repos/release
# INFO | SBOM guardado en results/release-sbom.json
# INFO | [20/25] Procesando repositorio miner/repos/satori
# INFO | SBOM guardado en results/satori-sbom.json
# INFO | [21/25] Procesando repositorio miner/repos/serve
# INFO | SBOM guardado en results/serve-sbom.json
# INFO | [22/25] Procesando repositorio miner/repos/streamdown
# INFO | SBOM guardado en results/streamdown-sbom.json
# INFO | [23/25] Procesando repositorio miner/repos/styled-jsx
# INFO | SBOM guardado en results/styled-jsx-sbom.json
# INFO | [24/25] Procesando repositorio miner/repos/swr
# INFO | SBOM guardado en results/swr-sbom.json
# INFO | [25/25] Procesando repositorio miner/repos/vercel
# INFO | SBOM guardado en results/vercel-sbom.json
# INFO | Resumen final | total_repos=25 | repos_generados=25 | archivos_generados=25 | errores=0

# %% [markdown]
# ## Paso 3: Analizar con CodeQL

# %%
from generate_codeql import CodeQLAnalyzer

codeql_analyzer = CodeQLAnalyzer(str(RUTA_REPOS), str(RUTA_RESULTADOS))
codeql_analyzer.run()
codeql_analyzer.run_cicd_analysis()
# Out:
# INFO | === Diagnóstico del Entorno CodeQL ===
# INFO | ✓ CodeQL CLI: CodeQL command-line toolchain release 2.27.0.
# INFO | ✓ Node.js: v20.20.2
# INFO | ✓ npm: 10.8.2
# INFO | Verificando query packs...
# INFO | ✓ Query pack codeql/python-queries disponible
# INFO | ✓ Query pack codeql/javascript-queries disponible
# INFO | ✓ Query pack codeql/java-queries disponible
# INFO | ✓ Query pack codeql/actions-queries disponible
# INFO | === Fin Diagnóstico ===
#
# INFO | [1/25] Procesando miner/repos/ai (código fuente)
# INFO | Lenguaje detectado en ai: javascript
# INFO | Directorio temporal CodeQL: /tmp/codeql_analysis
# INFO | Creando base de datos CodeQL para ai (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/ai_temp.sarif (7597438 bytes)
# INFO | parse_sarif: total_issues=911
# INFO | Análisis CodeQL guardado en results/ai-codeql.json (total_issues=911)
# INFO | [2/25] Procesando miner/repos/chatbot (código fuente)
# INFO | Lenguaje detectado en chatbot: javascript
# INFO | Creando base de datos CodeQL para chatbot (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/chatbot_temp.sarif (287955 bytes)
# INFO | parse_sarif: total_issues=4
# INFO | Análisis CodeQL guardado en results/chatbot-codeql.json (total_issues=4)
# INFO | [3/25] Procesando miner/repos/commerce (código fuente)
# INFO | Lenguaje detectado en commerce: javascript
# INFO | Creando base de datos CodeQL para commerce (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/commerce_temp.sarif (198078 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/commerce-codeql.json (total_issues=0)
# INFO | [4/25] Procesando miner/repos/eve (código fuente)
# INFO | Lenguaje detectado en eve: javascript
# INFO | Creando base de datos CodeQL para eve (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/eve_temp.sarif (3606014 bytes)
# INFO | parse_sarif: total_issues=194
# INFO | Análisis CodeQL guardado en results/eve-codeql.json (total_issues=194)
# INFO | [5/25] Procesando miner/repos/examples (código fuente)
# INFO | Lenguaje detectado en examples: javascript
# INFO | Creando base de datos CodeQL para examples (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/examples_temp.sarif (3190024 bytes)
# INFO | parse_sarif: total_issues=158
# INFO | Análisis CodeQL guardado en results/examples-codeql.json (total_issues=158)
# INFO | [6/25] Procesando miner/repos/hazel (código fuente)
# INFO | Lenguaje detectado en hazel: javascript
# INFO | Creando base de datos CodeQL para hazel (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/hazel_temp.sarif (161574 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/hazel-codeql.json (total_issues=0)
# INFO | [7/25] Procesando miner/repos/hyper (código fuente)
# INFO | Lenguaje detectado en hyper: javascript
# INFO | Creando base de datos CodeQL para hyper (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/hyper_temp.sarif (663533 bytes)
# INFO | parse_sarif: total_issues=673
# INFO | Análisis CodeQL guardado en results/hyper-codeql.json (total_issues=673)
# INFO | [8/25] Procesando miner/repos/micro (código fuente)
# INFO | Lenguaje detectado en micro: javascript
# INFO | Creando base de datos CodeQL para micro (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/micro_temp.sarif (182845 bytes)
# INFO | parse_sarif: total_issues=5
# INFO | Análisis CodeQL guardado en results/micro-codeql.json (total_issues=5)
# INFO | [9/25] Procesando miner/repos/ms (código fuente)
# INFO | Lenguaje detectado en ms: javascript
# INFO | Creando base de datos CodeQL para ms (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/ms_temp.sarif (160987 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/ms-codeql.json (total_issues=0)
# INFO | [10/25] Procesando miner/repos/ncc (código fuente)
# INFO | Lenguaje detectado en ncc: javascript
# INFO | Creando base de datos CodeQL para ncc (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/ncc_temp.sarif (348304 bytes)
# INFO | parse_sarif: total_issues=57
# INFO | Análisis CodeQL guardado en results/ncc-codeql.json (total_issues=57)
# INFO | [11/25] Procesando miner/repos/next-app-router-playground (código fuente)
# INFO | Lenguaje detectado en next-app-router-playground: javascript
# INFO | Creando base de datos CodeQL para next-app-router-playground (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/next-app-router-playground_temp.sarif (256791 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/next-app-router-playground-codeql.json (total_issues=1)
# INFO | [12/25] Procesando miner/repos/next-forge (código fuente)
# INFO | Lenguaje detectado en next-forge: javascript
# INFO | Creando base de datos CodeQL para next-forge (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/next-forge_temp.sarif (446715 bytes)
# INFO | parse_sarif: total_issues=5
# INFO | Análisis CodeQL guardado en results/next-forge-codeql.json (total_issues=5)
# INFO | [13/25] Procesando miner/repos/next-learn (código fuente)
# INFO | Lenguaje detectado en next-learn: javascript
# INFO | Creando base de datos CodeQL para next-learn (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/next-learn_temp.sarif (266217 bytes)
# INFO | parse_sarif: total_issues=13
# INFO | Análisis CodeQL guardado en results/next-learn-codeql.json (total_issues=13)
# INFO | [14/25] Procesando miner/repos/next.js (código fuente)
# INFO | Lenguaje detectado en next.js: javascript
# INFO | Creando base de datos CodeQL para next.js (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/next.js_temp.sarif (30533035 bytes)
# INFO | parse_sarif: total_issues=4009
# INFO | Análisis CodeQL guardado en results/next.js-codeql.json (total_issues=4009)
# INFO | [15/25] Procesando miner/repos/nextjs-subscription-payments (código fuente)
# INFO | Lenguaje detectado en nextjs-subscription-payments: javascript
# INFO | Creando base de datos CodeQL para nextjs-subscription-payments (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/nextjs-subscription-payments_temp.sarif (194986 bytes)
# INFO | parse_sarif: total_issues=7
# INFO | Análisis CodeQL guardado en results/nextjs-subscription-payments-codeql.json (total_issues=7)
# INFO | [16/25] Procesando miner/repos/og-image (código fuente)
# INFO | Lenguaje detectado en og-image: javascript
# INFO | Creando base de datos CodeQL para og-image (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/og-image_temp.sarif (160141 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/og-image-codeql.json (total_issues=0)
# INFO | [17/25] Procesando miner/repos/pkg (código fuente)
# INFO | Lenguaje detectado en pkg: javascript
# INFO | Creando base de datos CodeQL para pkg (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/pkg_temp.sarif (1032272 bytes)
# INFO | parse_sarif: total_issues=41
# INFO | Análisis CodeQL guardado en results/pkg-codeql.json (total_issues=41)
# INFO | [18/25] Procesando miner/repos/platforms (código fuente)
# INFO | Lenguaje detectado en platforms: javascript
# INFO | Creando base de datos CodeQL para platforms (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/platforms_temp.sarif (168138 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/platforms-codeql.json (total_issues=0)
# INFO | [19/25] Procesando miner/repos/release (código fuente)
# INFO | Lenguaje detectado en release: javascript
# INFO | Creando base de datos CodeQL para release (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/release_temp.sarif (161793 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/release-codeql.json (total_issues=0)
# INFO | [20/25] Procesando miner/repos/satori (código fuente)
# INFO | Lenguaje detectado en satori: javascript
# INFO | Creando base de datos CodeQL para satori (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/satori_temp.sarif (391171 bytes)
# INFO | parse_sarif: total_issues=15
# INFO | Análisis CodeQL guardado en results/satori-codeql.json (total_issues=15)
# INFO | [21/25] Procesando miner/repos/serve (código fuente)
# INFO | Lenguaje detectado en serve: javascript
# INFO | Creando base de datos CodeQL para serve (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/serve_temp.sarif (172779 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/serve-codeql.json (total_issues=1)
# INFO | [22/25] Procesando miner/repos/streamdown (código fuente)
# INFO | Lenguaje detectado en streamdown: javascript
# INFO | Creando base de datos CodeQL para streamdown (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/streamdown_temp.sarif (382831 bytes)
# INFO | parse_sarif: total_issues=3
# INFO | Análisis CodeQL guardado en results/streamdown-codeql.json (total_issues=3)
# INFO | [23/25] Procesando miner/repos/styled-jsx (código fuente)
# INFO | Lenguaje detectado en styled-jsx: javascript
# INFO | Creando base de datos CodeQL para styled-jsx (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/styled-jsx_temp.sarif (215568 bytes)
# INFO | parse_sarif: total_issues=19
# INFO | Análisis CodeQL guardado en results/styled-jsx-codeql.json (total_issues=19)
# INFO | [24/25] Procesando miner/repos/swr (código fuente)
# INFO | Lenguaje detectado en swr: javascript
# INFO | Creando base de datos CodeQL para swr (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/swr_temp.sarif (366955 bytes)
# INFO | parse_sarif: total_issues=13
# INFO | Análisis CodeQL guardado en results/swr-codeql.json (total_issues=13)
# INFO | [25/25] Procesando miner/repos/vercel (código fuente)
# INFO | Lenguaje detectado en vercel: javascript
# INFO | Creando base de datos CodeQL para vercel (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.4.5/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: results/vercel_temp.sarif (12497984 bytes)
# INFO | parse_sarif: total_issues=1009
# INFO | Análisis CodeQL guardado en results/vercel-codeql.json (total_issues=1009)
# INFO | Resumen final (código fuente) | total_repos=25 | repos_analizados=25 | archivos_generados=25 | errores=0
# INFO | === Diagnóstico del Entorno CodeQL ===
# INFO | ✓ CodeQL CLI: CodeQL command-line toolchain release 2.27.0.
# INFO | ✓ Node.js: v20.20.2
# INFO | ✓ npm: 10.8.2
# INFO | Verificando query packs...
# INFO | ✓ Query pack codeql/python-queries disponible
# INFO | ✓ Query pack codeql/javascript-queries disponible
# INFO | ✓ Query pack codeql/java-queries disponible
# INFO | ✓ Query pack codeql/actions-queries disponible
# INFO | === Fin Diagnóstico ===
#
# INFO | [1/25] Procesando miner/repos/ai (pipeline CI)
# INFO | Lenguaje detectado en ai: actions
# INFO | Creando base de datos CodeQL para ai (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/ai_pipeline_temp.sarif (3195920 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/ai-pipeline.json (total_issues=1)
# INFO | [2/25] Procesando miner/repos/chatbot (pipeline CI)
# INFO | Lenguaje detectado en chatbot: actions
# INFO | Creando base de datos CodeQL para chatbot (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/chatbot_pipeline_temp.sarif (239947 bytes)
# INFO | parse_sarif: total_issues=4
# INFO | Análisis CodeQL guardado en results/chatbot-pipeline.json (total_issues=4)
# INFO | [3/25] miner/repos/commerce sin flujo CI (.github/workflows). Se omite.
# INFO | [4/25] Procesando miner/repos/eve (pipeline CI)
# INFO | Lenguaje detectado en eve: actions
# INFO | Creando base de datos CodeQL para eve (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/eve_pipeline_temp.sarif (2001734 bytes)
# INFO | parse_sarif: total_issues=20
# INFO | Análisis CodeQL guardado en results/eve-pipeline.json (total_issues=20)
# INFO | [5/25] Procesando miner/repos/examples (pipeline CI)
# INFO | Lenguaje detectado en examples: actions
# INFO | Creando base de datos CodeQL para examples (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/examples_pipeline_temp.sarif (1274017 bytes)
# INFO | parse_sarif: total_issues=8
# INFO | Análisis CodeQL guardado en results/examples-pipeline.json (total_issues=8)
# INFO | [6/25] miner/repos/hazel sin flujo CI (.github/workflows). Se omite.
# INFO | [7/25] Procesando miner/repos/hyper (pipeline CI)
# INFO | Lenguaje detectado en hyper: actions
# INFO | Creando base de datos CodeQL para hyper (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/hyper_pipeline_temp.sarif (226449 bytes)
# INFO | parse_sarif: total_issues=8
# INFO | Análisis CodeQL guardado en results/hyper-pipeline.json (total_issues=8)
# INFO | [8/25] Procesando miner/repos/micro (pipeline CI)
# INFO | Lenguaje detectado en micro: actions
# INFO | Creando base de datos CodeQL para micro (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/micro_pipeline_temp.sarif (188762 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/micro-pipeline.json (total_issues=1)
# INFO | [9/25] Procesando miner/repos/ms (pipeline CI)
# INFO | Lenguaje detectado en ms: actions
# INFO | Creando base de datos CodeQL para ms (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/ms_pipeline_temp.sarif (186529 bytes)
# INFO | parse_sarif: total_issues=5
# INFO | Análisis CodeQL guardado en results/ms-pipeline.json (total_issues=5)
# INFO | [10/25] Procesando miner/repos/ncc (pipeline CI)
# INFO | Lenguaje detectado en ncc: actions
# INFO | Creando base de datos CodeQL para ncc (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/ncc_pipeline_temp.sarif (252042 bytes)
# INFO | parse_sarif: total_issues=0
# INFO | Análisis CodeQL guardado en results/ncc-pipeline.json (total_issues=0)
# INFO | [11/25] miner/repos/next-app-router-playground sin flujo CI (.github/workflows). Se omite.
# INFO | [12/25] Procesando miner/repos/next-forge (pipeline CI)
# INFO | Lenguaje detectado en next-forge: actions
# INFO | Creando base de datos CodeQL para next-forge (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/next-forge_pipeline_temp.sarif (329958 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/next-forge-pipeline.json (total_issues=1)
# INFO | [13/25] Procesando miner/repos/next-learn (pipeline CI)
# INFO | Lenguaje detectado en next-learn: actions
# INFO | Creando base de datos CodeQL para next-learn (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/next-learn_pipeline_temp.sarif (234567 bytes)
# INFO | parse_sarif: total_issues=3
# INFO | Análisis CodeQL guardado en results/next-learn-pipeline.json (total_issues=3)
# INFO | [14/25] Procesando miner/repos/next.js (pipeline CI)
# INFO | Lenguaje detectado en next.js: actions
# INFO | Creando base de datos CodeQL para next.js (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/next.js_pipeline_temp.sarif (10753736 bytes)
# INFO | parse_sarif: total_issues=22
# INFO | Análisis CodeQL guardado en results/next.js-pipeline.json (total_issues=22)
# INFO | [15/25] miner/repos/nextjs-subscription-payments sin flujo CI (.github/workflows). Se omite.
# INFO | [16/25] miner/repos/og-image sin flujo CI (.github/workflows). Se omite.
# INFO | [17/25] Procesando miner/repos/pkg (pipeline CI)
# INFO | Lenguaje detectado en pkg: actions
# INFO | Creando base de datos CodeQL para pkg (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/pkg_pipeline_temp.sarif (581773 bytes)
# INFO | parse_sarif: total_issues=2
# INFO | Análisis CodeQL guardado en results/pkg-pipeline.json (total_issues=2)
# INFO | [18/25] miner/repos/platforms sin flujo CI (.github/workflows). Se omite.
# INFO | [19/25] miner/repos/release sin flujo CI (.github/workflows). Se omite.
# INFO | [20/25] Procesando miner/repos/satori (pipeline CI)
# INFO | Lenguaje detectado en satori: actions
# INFO | Creando base de datos CodeQL para satori (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/satori_pipeline_temp.sarif (227756 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/satori-pipeline.json (total_issues=1)
# INFO | [21/25] Procesando miner/repos/serve (pipeline CI)
# INFO | Lenguaje detectado en serve: actions
# INFO | Creando base de datos CodeQL para serve (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/serve_pipeline_temp.sarif (194184 bytes)
# INFO | parse_sarif: total_issues=9
# INFO | Análisis CodeQL guardado en results/serve-pipeline.json (total_issues=9)
# INFO | [22/25] Procesando miner/repos/streamdown (pipeline CI)
# INFO | Lenguaje detectado en streamdown: actions
# INFO | Creando base de datos CodeQL para streamdown (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/streamdown_pipeline_temp.sarif (295279 bytes)
# INFO | parse_sarif: total_issues=3
# INFO | Análisis CodeQL guardado en results/streamdown-pipeline.json (total_issues=3)
# INFO | [23/25] Procesando miner/repos/styled-jsx (pipeline CI)
# INFO | Lenguaje detectado en styled-jsx: actions
# INFO | Creando base de datos CodeQL para styled-jsx (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/styled-jsx_pipeline_temp.sarif (209047 bytes)
# INFO | parse_sarif: total_issues=1
# INFO | Análisis CodeQL guardado en results/styled-jsx-pipeline.json (total_issues=1)
# INFO | [24/25] Procesando miner/repos/swr (pipeline CI)
# INFO | Lenguaje detectado en swr: actions
# INFO | Creando base de datos CodeQL para swr (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/swr_pipeline_temp.sarif (284097 bytes)
# INFO | parse_sarif: total_issues=5
# INFO | Análisis CodeQL guardado en results/swr-pipeline.json (total_issues=5)
# INFO | [25/25] Procesando miner/repos/vercel (pipeline CI)
# INFO | Lenguaje detectado en vercel: actions
# INFO | Creando base de datos CodeQL para vercel (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.35/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: results/vercel_pipeline_temp.sarif (3395346 bytes)
# INFO | parse_sarif: total_issues=24
# INFO | Análisis CodeQL guardado en results/vercel-pipeline.json (total_issues=24)
# INFO | Resumen final (pipeline CI) | total_repos=25 | repos_analizados=18 | archivos_generados=18 | omitidos=7 | errores=0

# %% [markdown]
# ## Paso 4: Analizar vulnerabilidades de dependencias con Grype

# %%
from generate_grype import GrypeAnalyzer

grype_analyzer = GrypeAnalyzer(str(RUTA_REPOS), str(RUTA_RESULTADOS))
grype_analyzer.run()
# Out:
# INFO | === Diagnóstico del Entorno Grype ===
# INFO | ✓ Grype CLI: Application:         grype
# Version:             0.118.0
# BuildDate:           2026-08-27T19:58:02Z
# GitCommit:           756eb9a24f7beeafb6871a24e943e8a3ae210695
# GitDescription:      v0.118.0
# Platform:            linux/amd64
# GoVersion:           go1.26.3
# Compiler:            gc
# Syft Version:        v1.51.1
# Supported DB Schema: 6
# INFO | ✓ Grype DB: Path:      /home/vscode/.cache/grype/db/6/vulnerability.db
# Schema:    v6.1.9
# Built:     2026-09-15T06:31:36Z
# From:      https://grype.anchore.io/databases/v6/vulnerability-db_v6.1.9_2026-09-15T00:33:48Z_1789453896.tar.zst?checksum=sha256%3Ada59e6799affd13b75ab62e1de533fff3a45f4efa6fe255ffd99e35109f82c60
# Status:    valid
# INFO | === Fin Diagnóstico ===
#
# INFO | [1/25] Escaneando miner/repos/ai con Grype...
# INFO | Manifests encontrados en ai: package.json, requirements.txt
# INFO | Ejecutando Grype en ai...
# INFO | Grype raw guardado en results/ai-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/ai-grype.json (total=245)
# INFO | [2/25] Escaneando miner/repos/chatbot con Grype...
# INFO | Manifests encontrados en chatbot: package.json
# INFO | Ejecutando Grype en chatbot...
# INFO | Grype raw guardado en results/chatbot-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/chatbot-grype.json (total=94)
# INFO | [3/25] Escaneando miner/repos/commerce con Grype...
# INFO | Manifests encontrados en commerce: package.json
# INFO | Ejecutando Grype en commerce...
# INFO | Grype raw guardado en results/commerce-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/commerce-grype.json (total=16)
# INFO | [4/25] Escaneando miner/repos/eve con Grype...
# INFO | Manifests encontrados en eve: package.json
# INFO | Ejecutando Grype en eve...
# INFO | Grype raw guardado en results/eve-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/eve-grype.json (total=213)
# INFO | [5/25] Escaneando miner/repos/examples con Grype...
# INFO | pyproject.toml: 15 requirements.txt generados, 0 omitidos
# INFO | Manifests encontrados en examples: Cargo.lock, Cargo.toml, Gemfile, Gemfile.lock, go.mod, go.sum, package-lock.json, package.json, requirements.txt
# INFO | Ejecutando Grype en examples...
# INFO | Grype raw guardado en results/examples-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/examples-grype.json (total=12271)
# INFO | [6/25] Escaneando miner/repos/hazel con Grype...
# INFO | Manifests encontrados en hazel: package.json, yarn.lock
# INFO | Ejecutando Grype en hazel...
# INFO | Grype raw guardado en results/hazel-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/hazel-grype.json (total=142)
# INFO | [7/25] Escaneando miner/repos/hyper con Grype...
# INFO | Manifests encontrados en hyper: package.json
# INFO | Ejecutando Grype en hyper...
# INFO | Grype raw guardado en results/hyper-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/hyper-grype.json (total=163)
# INFO | [8/25] Escaneando miner/repos/micro con Grype...
# INFO | Manifests encontrados en micro: package.json
# INFO | Ejecutando Grype en micro...
# INFO | Grype raw guardado en results/micro-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/micro-grype.json (total=62)
# INFO | [9/25] Escaneando miner/repos/ms con Grype...
# INFO | Manifests encontrados en ms: package.json
# INFO | Ejecutando Grype en ms...
# INFO | Grype raw guardado en results/ms-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/ms-grype.json (total=35)
# INFO | [10/25] Escaneando miner/repos/ncc con Grype...
# INFO | Manifests encontrados en ncc: package.json
# INFO | Ejecutando Grype en ncc...
# INFO | Grype raw guardado en results/ncc-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/ncc-grype.json (total=252)
# INFO | [11/25] Escaneando miner/repos/next-app-router-playground con Grype...
# INFO | Manifests encontrados en next-app-router-playground: package.json
# INFO | Ejecutando Grype en next-app-router-playground...
# INFO | Grype raw guardado en results/next-app-router-playground-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/next-app-router-playground-grype.json (total=6)
# INFO | [12/25] Escaneando miner/repos/next-forge con Grype...
# INFO | Manifests encontrados en next-forge: package.json
# INFO | Ejecutando Grype en next-forge...
# INFO | Grype raw guardado en results/next-forge-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/next-forge-grype.json (total=394)
# INFO | [13/25] Escaneando miner/repos/next-learn con Grype...
# INFO | Manifests encontrados en next-learn: package.json
# INFO | Ejecutando Grype en next-learn...
# INFO | Grype raw guardado en results/next-learn-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/next-learn-grype.json (total=332)
# INFO | [14/25] Escaneando miner/repos/next.js con Grype...
# INFO | Manifests encontrados en next.js: Cargo.lock, Cargo.toml, package.json
# INFO | Ejecutando Grype en next.js...
# INFO | Grype raw guardado en results/next.js-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/next.js-grype.json (total=1214)
# INFO | [15/25] Escaneando miner/repos/nextjs-subscription-payments con Grype...
# INFO | Manifests encontrados en nextjs-subscription-payments: package.json
# INFO | Ejecutando Grype en nextjs-subscription-payments...
# INFO | Grype raw guardado en results/nextjs-subscription-payments-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/nextjs-subscription-payments-grype.json (total=73)
# INFO | [16/25] Escaneando miner/repos/og-image con Grype...
# INFO | Manifests encontrados en og-image: package.json, yarn.lock
# INFO | Ejecutando Grype en og-image...
# INFO | Grype raw guardado en results/og-image-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/og-image-grype.json (total=16)
# INFO | [17/25] Escaneando miner/repos/pkg con Grype...
# INFO | Manifests encontrados en pkg: package.json, yarn.lock
# INFO | Ejecutando Grype en pkg...
# INFO | Grype raw guardado en results/pkg-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/pkg-grype.json (total=8)
# INFO | [18/25] Escaneando miner/repos/platforms con Grype...
# INFO | Manifests encontrados en platforms: package.json
# INFO | Ejecutando Grype en platforms...
# INFO | Grype raw guardado en results/platforms-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/platforms-grype.json (total=37)
# INFO | [19/25] Escaneando miner/repos/release con Grype...
# INFO | Manifests encontrados en release: package.json, yarn.lock
# INFO | Ejecutando Grype en release...
# INFO | Grype raw guardado en results/release-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/release-grype.json (total=19)
# INFO | [20/25] Escaneando miner/repos/satori con Grype...
# INFO | Manifests encontrados en satori: package.json
# INFO | Ejecutando Grype en satori...
# INFO | Grype raw guardado en results/satori-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/satori-grype.json (total=106)
# INFO | [21/25] Escaneando miner/repos/serve con Grype...
# INFO | Manifests encontrados en serve: package.json
# INFO | Ejecutando Grype en serve...
# INFO | Grype raw guardado en results/serve-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/serve-grype.json (total=80)
# INFO | [22/25] Escaneando miner/repos/streamdown con Grype...
# INFO | Manifests encontrados en streamdown: package.json
# INFO | Ejecutando Grype en streamdown...
# INFO | Grype raw guardado en results/streamdown-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/streamdown-grype.json (total=36)
# INFO | [23/25] Escaneando miner/repos/styled-jsx con Grype...
# INFO | Manifests encontrados en styled-jsx: package.json
# INFO | Ejecutando Grype en styled-jsx...
# INFO | Grype raw guardado en results/styled-jsx-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/styled-jsx-grype.json (total=32)
# INFO | [24/25] Escaneando miner/repos/swr con Grype...
# INFO | Manifests encontrados en swr: package.json
# INFO | Ejecutando Grype en swr...
# INFO | Grype raw guardado en results/swr-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/swr-grype.json (total=45)
# INFO | [25/25] Escaneando miner/repos/vercel con Grype...
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/pyproject.toml. Se omite: Failed to parse /workspaces/Proyecto-Ciberseguridad/miner/repos/vercel/pyproject.toml
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/packages/python/test/fixtures/49-oversized-lambda/pyproject.toml. Se omite: pip._internal.exceptions.MetadataGenerationFailed: metadata generation failed
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/packages/python/test/fixtures/51-litellm/pyproject.toml. Se omite: pip._internal.exceptions.DistributionNotFound: No matching distribution found for litellm==1.92.0
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/packages/python-analysis/test/fixtures/invalid-pyproject/pyproject.toml. Se omite: Error: Could not open file 'pyproject.toml': Could not parse 'pyproject.toml': Expected ']' at the end of a table declaration (at line 1, column 9)
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/packages/cli/test/fixtures/unit/commands/build/with-services-parallel/pyproject.toml. Se omite: Failed to parse /workspaces/Proyecto-Ciberseguridad/miner/repos/vercel/packages/cli/test/fixtures/unit/commands/build/with-services-parallel/pyproject.toml
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/packages/cli/test/fixtures/unit/commands/build/with-services-parallel/services/py-a/pyproject.toml. Se omite: pip._internal.exceptions.DistributionNotFound: No matching distribution found for py-shared
# WARNING | No se pudo generar requirements.txt desde miner/repos/vercel/packages/cli/test/fixtures/unit/commands/build/with-services-parallel/services/py-b/pyproject.toml. Se omite: pip._internal.exceptions.DistributionNotFound: No matching distribution found for py-shared
# INFO | pyproject.toml: 95 requirements.txt generados, 7 omitidos
# INFO | Manifests encontrados en vercel: Cargo.lock, Cargo.toml, Gemfile, Gemfile.lock, Pipfile, Pipfile.lock, go.mod, go.sum, package-lock.json, package.json, requirements.txt, yarn.lock
# INFO | Ejecutando Grype en vercel...
# INFO | Grype raw guardado en results/vercel-grype-raw.json
# INFO | Análisis Grype normalizado guardado en results/vercel-grype.json (total=16366)
# INFO | Resumen final | total_repos=25 | repos_analizados=25 | archivos_generados=50 | errores=0
